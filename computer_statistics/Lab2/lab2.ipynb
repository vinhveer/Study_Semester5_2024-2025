# %% [markdown]
# # Lab 2

# %% [markdown]
# ### Xây dựng histogram

# %% [markdown]
# ##### Demo

# %%
import pandas as pd

df = pd.DataFrame({
    'length': [1.5, 0.5, 1.2, 0.9, 3],
    'width': [0.7, 0.2, 0.15, 0.2, 1.1]
}, index=['pig', 'rabbit', 'duck', 'chicken', 'horse'])

histogram = df.hist(bins=3)

# %% [markdown]
# ##### Dùng hàm matplotlib.pyplot.hist

# %%
import matplotlib.pyplot as plt
import numpy as np

# Tạo dữ liệu ngẫu nhiên
a, b = 0, 30
data = np.random.uniform(0, 30, 100)

n, bins, patches = plt.hist(data, bins='auto', color='#0504aa', alpha=0.9, rwidth=0.8)

plt.grid(axis='y', alpha=0.75)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('My Very Own Histogram')

# Tính trung bình và độ lệch chuẩn cho phân phối đều
mu = (a + b) / 2
sigma = (b - a) / np.sqrt(12)
# Hiển thị μ và σ trên biểu đồ
plt.text(20, 18, r'$\mu=%.2f, \sigma=%.2f$' % (mu, sigma))

maxfreq = n.max()
plt.ylim(ymax=np.ceil(maxfreq/10)*10 if maxfreq % 10 else maxfreq + 10)
# Out:
# (0.0, 20.0)

# %% [markdown]
# ##### Dataset 15 (Practice)

# %%
import pandas as pd
import matplotlib.pyplot as plt

data_import = pd.read_excel('15_OLDFAITH.xls')
df = pd.DataFrame(data_import)

n, bins, patches = plt.hist(df['Duration'], bins='auto', color='#0504aa', alpha=0.9, rwidth=0.8)

plt.grid(axis='y', alpha=0.75)
plt.xlabel('Duration (giây)')
plt.ylabel('Frequency')
plt.title('Histogram of Duration')

# Tính trung bình và độ lệch chuẩn cho phân phối đều
mean_duration = df['Duration'].mean()
std_duration = df['Duration'].std()

# Hiển thị μ và σ trên biểu đồ
plt.text(80, 18, r'$\mu=%.2f, \sigma=%.2f$' % (mean_duration, std_duration))

plt.show()

# %% [markdown]
# ##### Dataset 17

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_excel('17_COLA.xls')
df = pd.DataFrame(data)

n, bins, patches = plt.hist(df['CKDIETWT'], bins='auto', color='#0504aa', alpha=0.9, rwidth=0.8)

plt.grid(axis='y', alpha=0.75)
plt.xlabel('CKDIETWT (pounds)')
plt.ylabel('Frequency')
plt.title('Histogram of CKDIETWT')

plt.show()

# %% [markdown]
# ### Xây dựng Scatterplot

# %% [markdown]
# ##### Dùng DataFrame của package Pandas

# %%
import pandas as pd

# Tạo DataFrame
data_frame = pd.DataFrame([[5.1, 3.5, 0],
                           [4.9, 3.0, 0],
                           [7.0, 3.2, 1],
                           [6.4, 3.2, 1],
                           [5.9, 3.0, 2]],
                          columns=['length', 'width', 'species'])

# Tạo biểu đồ scatter
ax1 = data_frame.plot.scatter(x='length', y='width', c='DarkBlue')
ax2 = data_frame.plot.scatter(x='length', y='width', c='species', colormap='viridis')

# %% [markdown]
# ##### Dùng hàm matplotlib.pyplot.scatter

# %%
import numpy as np
import matplotlib.pyplot as plt

# Tạo dữ liệu
x = np.random.randn(500)
y = np.random.randn(500)

colors = (0, 0, 0)
area = np.pi*3

# Vẽ biểu đồ
plt.scatter(x, y, s=area, color=colors, alpha=0.5)
plt.title('Scatter plot')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ##### Dataset 4: Nhựa/CO trong thuốc lá

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Đọc dữ liệu từ tệp Excel
data_frame = pd.read_excel('04_CIGARET.xls')

# Trích xuất các thuộc tính cần thiết từ DataFrame
real_tar_weight = data_frame['KgTar'] 
real_co_weight = data_frame['KgCO']   
mean_tar_weight = data_frame['MnTar'] 
mean_co_weight = data_frame['MnCO']   
low_tar_weight = data_frame['FLTar']  
low_co_weight = data_frame['FLCO']    

# Tạo một figure với 3 subplots
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# Biểu đồ 1: KgTar vs KgCO (Thực tế)
axs[0].scatter(real_tar_weight, real_co_weight, color='blue')
axs[0].set_title('KgTar vs KgCO (Real)')
axs[0].set_xlabel('Tar Weight (Kg)')
axs[0].set_ylabel('CO Weight (Kg)')

# Biểu đồ 2: MnTar vs MnCO (Trung bình)
axs[1].scatter(mean_tar_weight, mean_co_weight, color='green')
axs[1].set_title('MnTar vs MnCO (Mean)')
axs[1].set_xlabel('Tar Weight (Kg)')
axs[1].set_ylabel('CO Weight (Kg)')

# Biểu đồ 3: FLTar vs FLCO (Mức thấp)
axs[2].scatter(low_tar_weight, low_co_weight, color='red')
axs[2].set_title('FLTar vs FLCO (Low)')
axs[2].set_xlabel('Tar Weight (Kg)')
axs[2].set_ylabel('CO Weight (Kg)')

# Căn chỉnh khoảng cách giữa các subplots
plt.tight_layout()

# Hiển thị biểu đồ
plt.show()

# %% [markdown]
# ##### Dataset 12

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Đọc dữ liệu từ tệp Excel
data_frame = pd.read_excel('12_ELECTRIC.xls')

# Giả sử các cột tương ứng với nhiệt độ và tiêu thụ năng lượng là 'AvTemp' và 'kWh'
# Chọn 22 giá trị đầu tiên
average_temperature = data_frame['AvTemp'].head(22)  
energy_consumption = data_frame['kWh'].head(22)      

# Vẽ biểu đồ scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(average_temperature, energy_consumption, color='orange')
plt.title('Mối quan hệ giữa nhiệt độ trung bình hàng ngày và lượng tiêu thụ năng lượng')
plt.xlabel('Nhiệt độ trung bình (°C)')
plt.ylabel('Lượng tiêu thụ năng lượng (kWh)')
plt.grid(True)

# Hiển thị biểu đồ
plt.show()

# %% [markdown]
# ### Xây dựng Bar chart

# %% [markdown]
# ##### Dùng DataFrame của package Pandas

# %%
import pandas as pd
df = pd.DataFrame({'lab':['A', 'B', 'C'], 'val':[10, 30, 20]})
ax = df.plot.bar(x='lab', y='val', rot=0)

# %%
speeds = [0.1, 17.5, 40, 48, 52, 69, 88]
lifespan = [2, 8, 70, 1.5, 25, 12, 28]
index = ['snail', 'pig', 'elephant', 'rabbit', 'giraffe', 'coyote', 'horse']

df = pd.DataFrame({'speed': speeds, 'lifespan': lifespan}, index=index)
ax = df.plot.bar(rot=0)

# %% [markdown]
# ##### Dùng matplotlib.pyplot.bar

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np

object = ('Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp')
y_pos = np.arange(len(object))
performance = [10,8,6,4,2,1]

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, object)
plt.ylabel('Usage')
plt.title('Programming language usage')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Dữ liệu
n_groups = 4
means_frank = (90, 55, 40, 65)
means_guido = (85, 62, 54, 20)

# Tạo plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

rests1 = plt.bar(index, means_frank, bar_width, alpha=opacity, color='b', label='Frank')
rests2 = plt.bar(index + bar_width, means_guido, bar_width, alpha=opacity, color='r', label='Guido')

plt.xlabel('Person')
plt.ylabel('Scores')
plt.title('Scores by person')
plt.xticks(index + bar_width, ('A', 'B', 'C', 'D'))
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Xây dựng Pie Chart

# %% [markdown]
# ##### Dùng DataFrame của package Pandas

# %%
import pandas as pd

# Tạo DataFrame
df = pd.DataFrame({'mass': [0.330, 4.87 , 5.97, 0.642],
                    'radius': [2439.7, 6051.8, 6378.1, 3389.5]},
                    index=['Mercury', 'Venus', 'Earth', 'Mars'])

plot = df.plot.pie(y='mass', figsize=(5, 5))

# %% [markdown]
# ##### Dùng matplotlib.pyplot.pie

# %%
import matplotlib.pyplot as plt

# Dữ liệu
labels = ['Python', 'C++', 'Ruby', 'Java']
sizes = [215, 130, 245, 210]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0, 0)


# Tạo plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True)
plt.axis('equal')
plt.show()

# %%
import matplotlib.pyplot as plt
labels = ['cookies', 'jellybean', 'milkshake', 'cheesecake']
sizes = [38.4, 40.6, 20.7, 10.3]
colors = ['yellow', 'red', 'blue', 'green']
patches, texts = plt.pie(sizes, colors=colors, shadow=True, startangle=90)
plt.legend(patches, labels, loc="best")
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### **Bài tập 1:** Xây dựng bar char và pie char cho dữ liệu ở bảng sau. So sánh 2 biểu đồ trên, biểu đồ nào là hiệu quả hơn trong việc hiển thị thông tin

# %%
import matplotlib.pyplot as plt

# Data from the image
colleges = ['Public 2-Year', 'Public 4-Year', 'Private 2-Year', 'Private 4-Year']
relative_frequencies = [36.8, 40.0, 1.6, 21.9]

# Plotting a bar chart
plt.figure(figsize=(12, 5))

# Bar Chart
plt.subplot(1, 2, 1)
plt.bar(colleges, relative_frequencies, color='skyblue')
plt.title('Bar Chart of College Frequencies')
plt.xlabel('College Type')
plt.ylabel('Relative Frequency (%)')
plt.xticks(rotation=45)

# Pie Chart
plt.subplot(1, 2, 2)
plt.pie(relative_frequencies, labels=colleges, autopct='%1.1f%%', colors=['skyblue', 'orange', 'lightgreen', 'lightcoral'], startangle=140)
plt.title('Pie Chart of College Frequencies')

# Display both charts
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Tính các giá trị thống kê

# %% [markdown]
# **Nhiệt độ cơ thể:** Sử dụng nhiệt độ cơ thể lúc 12:00 AM vào ngày 2 từ Dataset 2. Các kết quả có hỗ trợ hoặc mâu thuẫn với phát biểu “nhiệt độ trung bình của cơ thể là 98,6°F” hay không?

# %%
import pandas as pd

# Đọc dữ liệu từ tệp Excel
data = pd.read_excel('02_BODYTEMP.xlsx')

# Kiểm tra xem cột 'DAY 2 - 12AM' có tồn tại không
if 'DAY 2 - 12AM' in data.columns:
    mean_value = data['DAY 2 - 12AM'].mean()   # Mean
    median_value = data['DAY 2 - 12AM'].median()  # Median
    std_value = data['DAY 2 - 12AM'].std()  # Standard Deviation
    var_value = data['DAY 2 - 12AM'].var()  # Variance
    max_value = data['DAY 2 - 12AM'].max()  # Maximum
    min_value = data['DAY 2 - 12AM'].min()  # Minimum
    
    # In kết quả
    print(f"Mean: {mean_value}")
    print(f"Median: {median_value}")
    print(f"Standard Deviation: {std_value}")
    print(f"Variance: {var_value}")
    print(f"Maximum: {max_value}")
    print(f"Minimum: {min_value}")
# Out:
# Mean: 98.19999999999999
# Median: 98.4
# Standard Deviation: 0.6228964600958975
# Variance: 0.38800000000000007
# Maximum: 99.6
# Minimum: 96.5

# %% [markdown]
# ### Xây dựng box plot

# %% [markdown]
# ##### Dùng Pandas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

np.random.seed(1234)

# Tạo dữ liệu ngẫu nhiên
df = pd.DataFrame(np.random.randn(10, 4), columns=['A', 'B', 'C', 'D'])

# Vẽ biểu đồ Boxplot
df.boxplot(column=['A', 'B', 'C', 'D'])

# Hiển thị biểu đồ
plt.show()

# %% [markdown]
# ##### Dùng matplotlib.pyplot.boxplot

# %%
import numpy as np
import matplotlib.pyplot as plt

# Đặt seed để đảm bảo tính tái lập của dữ liệu ngẫu nhiên
np.random.seed(137762361)

# Tạo dữ liệu
spread = np.random.rand(50) * 100  #
center = np.ones(25) * 50  
flier_high = np.random.rand(10) * 100 + 100 
flier_low = np.random.rand(10) * -100 

# Gộp tất cả dữ liệu lại với nhau
data = np.concatenate((spread, center, flier_high, flier_low))

# Tạo đồ thị boxplot
fig1, ax1 = plt.subplots()
ax1.set_title('Basic Plot')
ax1.boxplot(data)

# Chỉ gọi plt.show() một lần
plt.show()

# %% [markdown]
# **Trọng lượng của Coke thông thường và Coke ăn kiêng.** Sử dụng cùng một tỷ lệ để xây dựng box plot đối với trọng lượng của Coke thông thường và Coke ăn kiêng từ Dataset 17. Sử dụng box plot để so sánh hai bộ dữ liệu.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Đọc dữ liệu từ tệp Excel
data = pd.read_excel('17_COLA.xls')

# Tạo biểu đồ boxplot cho Coke thường và Coke ăn kiêng
fig, ax = plt.subplots()

# So sánh trọng lượng của Coke ăn kiêng và Coke thường trên cùng một biểu đồ
data[['CKDIETWT', 'CKREGWT']].boxplot(ax=ax)

# Đặt tiêu đề và nhãn cho biểu đồ
ax.set_title('Comparison of Coke Diet and Regular Weight')
ax.set_ylabel('Weight')
plt.suptitle('')  # Loại bỏ tiêu đề phụ mặc định của pandas boxplot

# Hiển thị biểu đồ
plt.show()

# %% [markdown]
# ### Kiểm tra dạng chuẩn

# %%
from numpy.random import seed, randn
from statsmodels.graphics.gofplots import qqplot
from matplotlib import pyplot

seed(1)

data = 5 * randn(100) + 50

qqplot(data, line='s')
pyplot.show()

# %% [markdown]
# **Old Faithful:** biểu đồ QQ-plot biểu diễn thời gian (tính bằng giây) phun trào Old Faithful từ Dataset 15.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

data = pd.read_excel('15_OLDFAITH.xls')

# Lấy dữ liệu từ cột 'Duration'
duration = data['Duration'].dropna()  # Bỏ các giá trị NaN nếu có

# Tạo biểu đồ QQ-plot
stats.probplot(duration, dist="norm", plot=plt)
plt.title('QQ-Plot for Old Faithful Eruption Duration')
plt.xlabel('Theoretical Quantiles')
plt.ylabel('Sample Quantiles')

# Hiển thị biểu đồ
plt.show()

# %% [markdown]
# **Chiều cao của phụ nữ:** biểu đồ QQ-plot biểu diễn chiều cao của phụ nữ từ dataset 1.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

data = pd.read_excel('01_FHEALTH.xls')

# Lấy dữ liệu từ cột 'HT'
height = data['HT'].dropna()  # Bỏ các giá trị NaN nếu có

# Tạo biểu đồ QQ-plot
stats.probplot(height, dist="norm", plot=plt)
plt.title('QQ-Plot for Height')
plt.xlabel('Theoretical Quantiles')
plt.ylabel('Sample Quantiles')

# Hiển thị biểu đồ
plt.show()

# %% [markdown]
# **Trọng lượng của Coke ăn kiêng:** biểu đồ QQ-plot biểu diễn trọng lượng (tính bằng pound) của Diet Coke từ Dataset 17

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

data = pd.read_excel('17_COLA.xls')

# Lấy dữ liệu từ cột 'CKDIETWT' (trọng lượng của Coke ăn kiêng)
diet_coke_weight = data['CKDIETWT'].dropna()  # Bỏ các giá trị NaN nếu có

# Tạo biểu đồ QQ-plot
stats.probplot(diet_coke_weight, dist="norm", plot=plt)
plt.title('QQ-Plot for Diet Coke Weight')
plt.xlabel('Theoretical Quantiles')
plt.ylabel('Sample Quantiles')

# Hiển thị biểu đồ
plt.show()
